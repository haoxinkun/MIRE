# %% [markdown]
# # 解析结果数据

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/test1/test1.csv")

# %%
df.rename(columns={"predict": "output"}, inplace=True)

# %%
df = df[df_demo.columns.to_list()]

# %%
df_demo = pd.read_json("../data/demo_test.json")

# %%
df_demo.loc[0, ["image"]].values
# Out:
# array([list(['save/images/2127e96c17273966761471590d0b0d-0.jpg'])],
#       dtype=object)

# %%
import ast
df['image'] = df['image'].apply(ast.literal_eval)
df["image"] = df["image"].apply(lambda x: [f"save/images/{ele}" for ele in x])
# Out:
# /tmp/ipykernel_867707/479155432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['image'] = df['image'].apply(ast.literal_eval)
# /tmp/ipykernel_867707/479155432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["image"] = df["image"].apply(lambda x: [f"save/images/{ele}" for ele in x])

# %%
def df_get_output(x):
    res = ""
    if "[" not in x:
        return x.strip('"')
    try:
        res = ast.literal_eval(x)[0]
    except Exception as e:
        print("结果异常" + x)
    return res

# %%
df["output"] = df["output"].apply(df_get_output)
# Out:
# 结果异常["反馈密封性不好","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","商品规格","信号
# 结果异常["反馈密封性不好","是否好用","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","
# 结果异常["反馈密封性不好","是否好用","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","
# 结果异常["反馈密封性不好","是否好用","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","
# 结果异常["商品材质", "功效功能", "是否易褪色", "适用季节", "能否调光", "版本款型区别", "单品推荐", "用法用量", "控制方式", "上市时间", "商品规格", "信号情况", "养护方法", "套装推荐", "何时
# 结果异常["反馈密封性不好","是否好用","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","
# 结果异常["反馈密封性不好","是否好用","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","
# ...

# %%
df
# Out:
#                                               id  \
# 0                 21084b9217277750918824374d0ac0
# 1                 2107aafc17275075590991184d100c
# 2                 2132d91b17276822460003292d0b16
# 3                 0b5dcf7c17274819873488776d0aa6
# 4                 212c48dd17272677135588098d0fe4
# ...                                          ...
# 9995  0ac29978-937a-4a4b-b969-217c4a96dafa-12428
# 9996   d745beca-d152-413d-8c78-e55397bf6fd0-2294
# 9997   0eb16b16-1a2e-4fe6-b1e9-60214846fe8d-6580
# 9998   4bfeda8e-6585-4544-9889-5c56f335e21d-6148
# 9999  df53292c-b999-4882-88b3-85e9d8c80354-14757
#
#                                             instruction  input     output  \
# 0     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN       排水方式
# 1     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN       控制方式
# 2     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN       适用季节
# 3     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN    反馈密封性不好
# ...

# %%
df.to_csv("../data/test1_submit_20241216.csv", index=False, encoding="utf-8")

# %%
df["predict"] = df["output"]
# Out:
# /tmp/ipykernel_867707/1295716115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["predict"] = df["output"]

# %%
df["output"] = ""
# Out:
# /tmp/ipykernel_867707/2653676155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["output"] = ""

# %%
df
# Out:
#                                               id  \
# 0                 21084b9217277750918824374d0ac0
# 1                 2107aafc17275075590991184d100c
# 2                 2132d91b17276822460003292d0b16
# 3                 0b5dcf7c17274819873488776d0aa6
# 4                 212c48dd17272677135588098d0fe4
# ...                                          ...
# 9995  0ac29978-937a-4a4b-b969-217c4a96dafa-12428
# 9996   d745beca-d152-413d-8c78-e55397bf6fd0-2294
# 9997   0eb16b16-1a2e-4fe6-b1e9-60214846fe8d-6580
# 9998   4bfeda8e-6585-4544-9889-5c56f335e21d-6148
# 9999  df53292c-b999-4882-88b3-85e9d8c80354-14757
#
#                                             instruction  input output  \
# 0     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN
# 1     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN
# 2     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN
# 3     你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对...    NaN
# ...

# %%
df.to_csv("../data/test1_submit_20241215.csv", index=False, encoding="utf-8-sig")

# %%
df[df["predict"] == ""].iloc[0, 1]
# Out:
# '你是一个电商客服专家，请根据用户与客服的多轮对话判断用户的意图分类标签。\n<用户与客服的对话 START>\n用户: "<http>"\n客服: "✨「品牌钢化膜」 🔸 适用：某品牌手机7-16系列 🔸 特点：提供超清/防蓝光/防绿光/磨砂/抗指纹多种选择 🛒感兴趣的话赶紧入手吧~"\n用户: \n客服: 暂时无法解析您的图片内容，能否提供产品的网址链接，或通过文字说明一下遇到的问题呢？\n用户: 为什么这两片贴膜都出现这种情况，使用没多久就有一个很大的气泡。\n客服: 🔸 使用水凝膜时出现的气泡，一般会在大约一天的时间内自行消散。  🔸 对于钢化膜上出现的气泡，可以采取以下步骤解决。  1、如果气泡中有异物： 轻轻地移除膜，利用清洁贴去除气泡中的异物，之后再小心地重新贴上膜。  2、如果气泡中没有异物： 您可以尝试用卡片或类似工具，将气泡向边缘推挤。\n<用户与客服的对话 END>\n请直接只输出分类标签结果，不需要其他多余的话。以下是可以参考的分类标签为：["反馈密封性不好","是否好用","是否会生锈","排水方式","包装区别","发货数量","反馈用后症状","商品材质","功效功能","是否易褪色","适用季节","能否调光","版本款型区别","单品推荐","用法用量","控制方式","上市时间","商品规格","信号情况","养护方法","套装推荐","何时上货","气泡"]\n'

# %%
df.iloc[9999, 1]
# Out:
# 'Picture 1: \n你是一个电商领域识图专家,可以理解消费者上传的软件截图或实物拍摄图。现在,请你对消费者上传的图片进行分类。你只需要回答图片分类结果,不需要其他多余的话。以下是可以参考的分类标签,分类标签:["实物拍摄(含售后)","商品分类选项","商品头图","商品详情页截图","下单过程中出现异常（显示购买失败浮窗）","订单详情页面","支付页面","消费者与客服聊天页面","评论区截图页面","物流页面-物流列表页面","物流页面-物流跟踪页面","物流页面-物流异常页面","退款页面","退货页面","换货页面","购物车页面","店铺页面","活动页面","优惠券领取页面","账单/账户页面","个人信息页面","投诉举报页面","平台介入页面","外部APP截图","其他类别图片"]。'
